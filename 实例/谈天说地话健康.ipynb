# %%
# https://www.ximalaya.com/jiankang/47246515/
# https://www.ximalaya.com/revision/play/v1/audio?id=398017219&ptype=1
# "src": "https://aod.cos.tx.xmcdn.com/storages/82a9-audiofreehighqps/EB/20/CKwRIaIELxs2ACnqGACVmau-.m4a",

# %%
import requests
from bs4 import BeautifulSoup
import re
import json
from selenium import webdriver

# %%
def getResponse(url, param = {}):
    headers = {
        'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36'
    }
    response = requests.get(url=url, headers=headers, params=param)
    return response

# %%
# 获取页面的html文件
def getHTML(url):
    return getResponse(url).text

# %%
# 通过音频源地址爬取音频
def getAudio(url, id):
    response = getResponse(url)
    path = 'm4a/'
    #fileName = url.split('/')[-1]
    with open(path + id + '.m4a', 'wb') as fp:
        fp.write(response.content)

# %%
#getAudio('https://aod.cos.tx.xmcdn.com/storages/82a9-audiofreehighqps/EB/20/CKwRIaIELxs2ACnqGACVmau-.m4a')

# %%
url = 'https://www.ximalaya.com/jiankang/47246515/398889061'
html = getHTML(url)

# %%
print(html)
# Out:
# <!DOCTYPE html><html><head><title>打HPV疫苗前，需要进行HPV感染检查吗？-喜马拉雅</title><meta charSet="utf-8"/><meta http-equiv="x-dns-prefetch-control" content="on"/><meta name="keywords" content="打HPV疫苗前，需要进行HPV感染检查吗？,健康,两性健康,女性健康,女性,谭先杰"/><meta name="description" content="各位听友好，欢迎收听由喜马拉雅与健康百科独家打造的“谭天说地话健康”，本节目由北京协和医院妇产科主任医师、博士研究生导师谭先杰教授播讲。 大家好，我是北京协和医院的妇产科医生谭先杰，我们接着聊宫颈癌预防的话题。关于宫颈癌疫苗的问题，真的是比较多，那么今天我们继续来进行解答。 有一个问题就是说，接种HP*疫苗之前，需不需要检查HP*的感染，也就说是不是需要HP*检查阴性，才可以打HP*疫苗。答案是否..."/><meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1"/><meta content="webkit" name="renderer"/><meta http-equiv="X-UA-Compatible" content="chrome=1"/><meta name="applicable-device" content="pc,mobile"/><meta http-equiv="Cache-Control" content="no-transform"/><meta http-equiv="Cache-Control" content="no-siteapp"/><meta name="google-site-verification" content="Ndgaz7H1uQvWACwf_q2IxyLYxBnomEREr1P_EsPq1GI"/><meta property="og:title" content="打HPV疫苗前，需要进行HPV感染检查吗？-喜马拉雅"/><meta property="og:description" content="各位听友好，欢迎收听由喜马拉雅与
# ...

# %%
"""
<article class="intro  eX_"><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">各位听友好，欢迎收听由喜马拉雅与健康百科独家打造的“谭天说地话健康”，本节目由北京协和医院妇产科主任医师、博士研究生导师谭先杰教授播讲。</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">&nbsp;</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">大家好，我是北京协和医院的妇产科医生谭先杰，我们接着聊宫颈癌预防的话题。关于宫颈癌疫苗的问题，真的是比较多，那么今天我们继续来进行解答。</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">&nbsp;</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">有一个问题就是说，接种HPV疫苗之前，需不需要检查HPV的感染，也就说是不是需要HPV检查阴性，才可以打HPV疫苗。答案是否定的。也就是说我们打HPV疫苗之前，接种之前，并不需要你提供HPV检测阴性的证据，就相当于不需要核酸阴性的证据。无论你是阳性或者阴性，理论上你都可以打，这一点毫无疑问。也就是说，打的时候不需要你先检测HPV病毒是否感染，然后才可以给你打，你预约的时候，他不会管你的HPV的感染状态。</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">&nbsp;</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">但是我作为医生，作为工作了这么多年的临床医生，作为整天在和宫颈癌和宫颈病变打交道的一个妇科肿瘤医生，我建议比较特别，尽管说明书上没有要求你接种HPV疫苗之前要进行HPV检测，或者说由于你是一个少女，还没有进行过性行为，没有办法进行HPV的检测，那么我一般都建议，比如说20多岁以后的，或者说那种结婚也比较久了，或者有性生活时间比较长了的这些人，你在接种HPV疫苗之前，不妨去做一个HPV的检测。</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">&nbsp;</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">为什么呢？因为宫颈癌疫苗的接种，它属于宫颈癌的一级防控措施，而宫颈癌的筛查，属于宫颈癌的二级防控措施。这个时候如果你要不去检查，你就光接种了HPV疫苗，这个HPV疫苗我们都知道，它不会对已经发生的病变产生任何作用，对已经感染的HPV病毒它也没有作用，那么你如果不去筛查，你觉得打了一针之后，你就特别地高枕无忧，那可能就错了！</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">&nbsp;</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">因为在我门诊当中，碰到过这些在国外打了HPV疫苗，打之前当然没有检测，但回来之后因为其他种种的症状，查出来是HPV的感染，她就说是不是HPV疫苗没有效果？其实我想告诉她，这未必是HPV疫苗没有效果，而是说在你接种HPV疫苗之前，你已经有HPV的感染了。</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">&nbsp;</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">所以对这些年龄稍微比较大一点的女孩子，或者说性行为的年限比较长的女孩子，我建议你接种HPV疫苗之前，还是要做一个HPV的检测或者宫颈的防癌筛查。如果查出了问题，先把问题搞清楚、搞明白，把现在已经存在的病变治疗好了，再来说疫苗接种的事，否则你就会觉得我打了疫苗就没事了，然后还疏忽了，大意了，以后就发生一些大的问题。这就是说，接种HPV疫苗之前不强求，或者说不规定你要去做HPV的检测，但是如果你有条件，还是要进行HPV的筛查。</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">&nbsp;</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">另外一个问题就来了，是不是接种HPV疫苗之后，就一针了之，就不要继续做宫颈癌的筛查了呢？那不对！接种HPV疫苗之后，依然要定期地做宫颈癌的筛查，为什么呢？因为我们前面讲到，HPV疫苗的接种，属于宫颈癌的一级防控措施，筛查是宫颈癌的二级防控措施，这两个不是在一个水平上。</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">&nbsp;</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">HPV疫苗它是一个很好的防线，但它并不完美，为什么呢？2价的HPV疫苗能够对抗16、18，现在还认为可以对抗31、33、45、52，也就是说顶多它可以对抗6种HPV病毒；4价疫苗目前标称是对抗16、18；9价是对抗的16，18、31、33、45、52、58，7种类型的HPV病毒。</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">&nbsp;</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">无论是2价、4价还是9价，你看目前它能对抗的也就是2种到7种，还有7种到12种HPV病毒还得不到对抗，这是一方面。另外一方面，尽管科学家们现在认为引起宫颈癌的高危型的HPV病毒是14种，但实际上有些得了宫颈癌的患者或者宫颈病变的患者，她的HPV检测是阴性的，这就表明可能还有15种、16种、17种这种少见的HPV病毒，它还在路上，还没有被科学家们发现，这些疫苗对它们根本就没有对抗作用。</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">&nbsp;</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">所以说接种HPV疫苗之后，一定还要按时地去做宫颈癌的筛查，这一点是非常重要的，HPV疫苗不能一针了之！好的，今天的节目就到这了。</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">&nbsp;</p><p style="color:#333333;font-weight:normal;font-size:16px;line-height:30px;font-family:Helvetica,Arial,sans-serif;hyphens:auto;text-align:justify;" data-flag="normal">欢迎大家持续关注<strong style="color:#FC5832;word-break:break-all;font-family:Helvetica,Arial,sans-serif;font-weight: normal;">“谭天说地话健康”，我是协和谭先杰，喜欢我请关注、评论、点赞，有问题请在评论区留言，我在这里等你！</strong></p></article>
"""

# %%
# 获取语音对应的文本
def getAudioText(html):    
    ex = '<article class="intro  eX_">(.*?)</article>'
    audio_text = re.findall(ex, html, re.S)
    ex = 'data-flag="normal">(.*?)</p>'
    audio_text = re.findall(ex, audio_text[0], re.S)
    text = "\n".join(audio_text)
    return text

# %%
print(getAudioText(html))
# Out:
# 各位听友好，欢迎收听由喜马拉雅与健康百科独家打造的“谭天说地话健康”，本节目由北京协和医院妇产科主任医师、博士研究生导师谭先杰教授播讲。
# &nbsp;
# 大家好，我是北京协和医院的妇产科医生谭先杰，我们接着聊宫颈癌预防的话题。关于宫颈癌疫苗的问题，真的是比较多，那么今天我们继续来进行解答。
# &nbsp;
# 有一个问题就是说，接种HPV疫苗之前，需不需要检查HPV的感染，也就说是不是需要HPV检查阴性，才可以打HPV疫苗。答案是否定的。也就是说我们打HPV疫苗之前，接种之前，并不需要你提供HPV检测阴性的证据，就相当于不需要核酸阴性的证据。无论你是阳性或者阴性，理论上你都可以打，这一点毫无疑问。也就是说，打的时候不需要你先检测HPV病毒是否感染，然后才可以给你打，你预约的时候，他不会管你的HPV的感染状态。
# &nbsp;
# 但是我作为医生，作为工作了这么多年的临床医生，作为整天在和宫颈癌和宫颈病变打交道的一个妇科肿瘤医生，我建议比较特别，尽管说明书上没有要求你接种HPV疫苗之前要进行HPV检测，或者说由于你是一个少女，还没有进行过性行为，没有办法进行HPV的检测，那么我一般都建议，比如说20多岁以后的，或者说那种结婚也比较久了，或者有性生活时间比较长了的这些人，你在接种HPV疫苗之前，不妨去做一个HPV的检测。
# &nbsp;
# 为什么呢？因为宫颈癌疫苗的接种，它属于宫颈癌的一级防控措施，而宫颈癌的筛查，属于宫颈癌的二级防控措施。这个时候如果你要不去检查，你就光接种了HPV疫苗，这个HPV疫苗我们都知道，它不会对已经发生的病变产生任何作用，对已经感染的HPV病毒它也没有作用，那么你如果不去筛查，你觉得打了一针之后，你就特别地高枕无忧，那可能就错了！
# &nbsp;
# 因为在我门诊当中，碰到过这些在国外打了HPV疫苗，打之前当然没有检测，但回来之后因为其他种种的症状，查出来是HPV的感染，她就说是不是HPV疫苗没有效果？其实我想告诉她，这未必是HPV疫苗没有效果，而是说在你接种HPV疫苗之前，你已经有HPV的感染了。
# &nbsp;
# ...

# %%
# https://www.ximalaya.com/revision/play/v1/audio?id=398889061&ptype=1

# %%
"""
id: 398017219
ptype: 1
"""
# id 可以从前面获取得到
# ptype 都是1

# %%
# 获取音频源地址
# 通过get请求 返回的json数据中得到音频地址
# 
def getAudioSrcUrl(id):
    url = 'https://www.ximalaya.com/revision/play/v1/audio'
    param = {
        'id': id,
        'ptype': '1',
    }
    response = getResponse(url=url, param=param)
    dic_obj = response.json()
    return dic_obj['data']['src']

# %%
print(getAudioSrcUrl('398017219'))
# Out:
# https://aod.cos.tx.xmcdn.com/storages/82a9-audiofreehighqps/EB/20/CKwRIaIELxs2ACnqGACVmau-.m4a

# %%
# <a title="打HPV疫苗前，需要进行HPV感染检查吗？" href="/jiankang/47246515/398889061"><span class="title lF_">打HPV疫苗前，需要进行HPV感染检查吗？</span></a>

# %%
# 通过首页获取各个音频页面地址
def getAllUrlForEveryPage(url):
    html = getHTML(url=url)
    soup = BeautifulSoup(html, 'html.parser')
    all_a_href = soup.find_all('a')
    linkLists = []
    for href in all_a_href:
        temp = str(href)
        matchObj = re.match(r'<a title="(.*?)href="/jiankang/47246515/.*', temp, re.M|re.I)
        if matchObj:
            ex = '<a href="(.*?).html'
            temp = re.findall(ex, temp, re.S)
            linkLists.append(temp[0] + '.html')
    linkLists = list(set(linkLists))
    return linkLists

# %%
url = 'https://www.ximalaya.com/jiankang/47246515/'
html = getHTML(url)
print(html)
# Out:
# <!DOCTYPE html><html><head><title>谭天说地话健康在线收听-喜马拉雅</title><meta charSet="utf-8"/><meta http-equiv="x-dns-prefetch-control" content="on"/><meta name="keywords" content="谭天说地话健康,健康,两性健康,女性健康,女性,谭先杰"/><meta name="description" content="各位听友大家好，我是北京协和医院妇产科医生谭先杰，很荣幸参与到喜马拉雅当中来，我希望用我的声音给大家带去健康科普，守护女性健康。我写了两本书《10天，让你避开宫颈癌》和《子宫情事》，如果你是一位爱学习的听友，可以在我的橱窗里面购买进行学习，有问题可以与我交流。在本专辑中，我将用最通俗，易懂的语言来给大家聊一聊女性健康的问题，主要以宫颈癌，女性日常生活预防，生殖健康的保养以及孕产知识来给大家科谱，如..."/><meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1"/><meta content="webkit" name="renderer"/><meta http-equiv="X-UA-Compatible" content="chrome=1"/><meta name="applicable-device" content="pc,mobile"/><meta http-equiv="Cache-Control" content="no-transform"/><meta http-equiv="Cache-Control" content="no-siteapp"/><meta name="google-site-verification" content="Ndgaz7H1uQvWACwf_q2IxyLYxBnomEREr1P_EsPq1GI"/><meta property="og:title" content="谭天说地话健康在线收听-喜马拉雅"/><meta property="og:description" content="各位听友大家好，我是北京协和医院妇产科医生谭先杰，很荣幸参与到喜马拉雅当中来，我希望用我的声音给大家
# ...

# %%
ex = 'href="/jiankang/47246515/(.*?)">'
all_id = re.findall(ex, html, re.S)

# %%
for id in all_id:
    print(id)
# Out:
# 398889061
# 398017219
# 397024498
# 397020818
# 396408416
# 395688044
# 394381187
# 393760533
# 393761552
# 393089049
# 392763708
# 392668488
# 392525607
# 392477035
# 392430487
# 392115267

# %%
print(len(all_id))
# Out:
# 17

# %%
for id in all_id:
    print(id)
# Out:
# 398889061
# 398017219
# 397024498
# 397020818
# 396408416
# 395688044
# 394381187
# 393760533
# 393761552
# 393089049
# 392763708
# 392668488
# 392525607
# 392477035
# 392430487
# 392115267

# %%
all_id.pop(11)
# Out:
# '392668488'

# %%
for id in all_id:
    print(id)
# Out:
# 398889061
# 398017219
# 397024498
# 397020818
# 396408416
# 395688044
# 394381187
# 393760533
# 393761552
# 393089049
# 392763708
# 392525607
# 392477035
# 392430487
# 392115267

# %%
for id in all_id:
    print(id)
    if id == 392668488:
        print('continue')
        continue
    url = 'https://www.ximalaya.com/jiankang/47246515/' + str(id)
    html = getHTML(url)
    text = getAudioText(html)
    with open('text/' + str(id) + '.txt', 'w', encoding='utf-8') as fp:
        fp.write(text)
    srcUrl = getAudioSrcUrl(str(id))
    getAudio(srcUrl, str(id))
    print(str(id), "Successful")
# Out:
# 398889061
# 398889061 Successful
# 398017219
# 398017219 Successful
# 397024498
# 397024498 Successful
# 397020818
# 397020818 Successful
# 396408416
# 396408416 Successful
# 395688044
# 395688044 Successful
# 394381187
# 394381187 Successful
# 393760533
# 393760533 Successful
# 393761552
# 393761552 Successful
# 393089049
# 393089049 Successful
# 392763708
# 392763708 Successful
# 392525607
# 392525607 Successful
# 392477035
# 392477035 Successful
# 392430487
# 392430487 Successful
# 392115267
# 392115267 Successful
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-50232abdd973> in <module>
#       6     url = 'https://www.ximalaya.com/jiankang/47246515/' + str(id)
#       7     html = getHTML(url)
# ----> 8     text = getAudioText(html)
#       9     with open('text/' + str(id) + '.txt', 'w', encoding='utf-8') as fp:
#      10         fp.write(text)
#
# ...
